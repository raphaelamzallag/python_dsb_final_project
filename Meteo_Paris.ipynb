# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import LabelEncoder
import utils

# %%
df = pd.read_csv('meteo_paris.csv')
df
# Out:
#       name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0    paris  2020-09-01     21.4     11.5  16.1          21.4          11.5
# 1    paris  2020-09-02     22.0     11.2  16.8          22.0          11.2
# 2    paris  2020-09-03     26.9     15.3  21.3          26.7          15.3
# 3    paris  2020-09-04     28.6     18.1  23.2          27.6          18.1
# 4    paris  2020-09-05     20.1     15.4  17.7          20.1          15.4
# ..     ...         ...      ...      ...   ...           ...           ...
# 369  paris  2021-09-05     29.3     18.2  22.5          29.7          18.2
# 370  paris  2021-09-06     29.5     17.4  23.5          29.2          17.4
# 371  paris  2021-09-07     29.6     16.6  23.3          28.5          16.6
# 372  paris  2021-09-08     30.2     17.4  23.4          30.5          17.4
# 373  paris  2021-09-09     26.3     19.8  22.1          26.3          19.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              374 non-null    object
#  1   datetime          374 non-null    object
#  2   tempmax           374 non-null    float64
#  3   tempmin           374 non-null    float64
#  4   temp              374 non-null    float64
#  5   feelslikemax      374 non-null    float64
#  6   feelslikemin      374 non-null    float64
#  7   feelslike         374 non-null    float64
#  8   dew               374 non-null    float64
#  9   humidity          374 non-null    float64
#  10  precip            374 non-null    float64
#  11  precipprob        374 non-null    int64
#  12  precipcover       374 non-null    float64
#  13  preciptype        240 non-null    object
#  14  snow              374 non-null    int64
#  15  snowdepth         374 non-null    float64
# ...

# %%
columns_to_keep = ['datetime', 'temp', 'precip', 'windspeed', 'visibility']
df_n = df[columns_to_keep]
df_n.head()
# Out:
#      datetime  temp  precip  windspeed  visibility
# 0  2020-09-01  16.1   0.000       13.6        25.1
# 1  2020-09-02  16.8   0.000       11.1        24.1
# 2  2020-09-03  21.3   0.000       17.2        25.6
# 3  2020-09-04  23.2   0.000       15.8        25.4
# 4  2020-09-05  17.7   0.016       18.3        25.0

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    374 non-null    object
#  1   temp        374 non-null    float64
#  2   precip      374 non-null    float64
#  3   windspeed   374 non-null    float64
#  4   visibility  374 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 14.7+ KB

# %%
df_n.nunique()
# Out:
# datetime      374
# temp          180
# precip        192
# windspeed     177
# visibility    137
# dtype: int64

# %%
df['icon'].unique()
# Out:
# array(['partly-cloudy-day', 'cloudy', 'rain', 'clear-day', 'snow'],
#       dtype=object)

# %%
mapping = {'snow': 0, 'rain': 1, 'cloudy': 2, 'partly-cloudy-day': 3, 'clear-day': 4}
df_n.loc[:, 'icon_encoded'] = df['icon'].map(mapping)
# Out:
# /var/folders/rx/rlnnk9hd4dbfg0t2drhsrvyw0000gn/T/ipykernel_25261/3135373508.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n.loc[:, 'icon_encoded'] = df['icon'].map(mapping)

# %%
df_n.head()
# Out:
#      datetime  temp  precip  windspeed  visibility  icon_encoded
# 0  2020-09-01  16.1   0.000       13.6        25.1             3
# 1  2020-09-02  16.8   0.000       11.1        24.1             3
# 2  2020-09-03  21.3   0.000       17.2        25.6             2
# 3  2020-09-04  23.2   0.000       15.8        25.4             3
# 4  2020-09-05  17.7   0.016       18.3        25.0             1
