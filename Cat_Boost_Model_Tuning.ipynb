# %% [markdown]
# # Imports

# %%
 import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import utils
from pathlib import Path
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, Pipeline
from lockdowndates.core import LockdownDates
from jours_feries_france import JoursFeries
from vacances_scolaires_france import SchoolHolidayDates

from catboost import CatBoostRegressor
import datetime
from datetime import timedelta, date

# %%
X, y = utils.get_train_data()
X_final_test = pd.read_parquet(Path("data") / "final_test.parquet")

# %%
X_train, y_train, X_test, y_test = utils.train_test_split_temporal(X, y, delta_threshold="30 days")

# %%
def train_test_split_temporal(X, y, delta_threshold="30 days"):
    cutoff_date = X["date"].max() - pd.Timedelta(delta_threshold)
    mask = X["date"] <= cutoff_date
    X_train, X_test = X.loc[mask], X.loc[~mask]
    y_train, y_test = y[mask], y[~mask]

    return X_train, y_train, X_test, y_test

def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X["year"] = X["date"].dt.year
    X["month"] = X["date"].dt.month
    X["day"] = X["date"].dt.day
    X["weekday"] = X["date"].dt.weekday
    X["hour"] = X["date"].dt.hour

    # Finally we can drop the original columns from the dataframe
    return X.drop(columns=["date"])

def filter_columns(X):
    columns_to_keep = ['date', 'latitude', 'longitude']
    return X[columns_to_keep]

# %% [markdown]
# # Cat Boost

# %%
def create_rain(X):
    X['rain'] = X['icon_encoded'].map(lambda x: 1 if x == 1 else 0)
    return X

# %%
cat = CatBoostRegressor(
    depth=10,
    iterations=250,
    rsm=0.25,
    sampling_frequency="PerTree",
    subsample=0.7,
    verbose=0,
)

date_cols = FunctionTransformer(utils._encode_dates)
add_weather = FunctionTransformer(utils.create_x_weather)
keep_specific_columns = FunctionTransformer(utils.filter_columns)
add_vacances_et_jours_feries = FunctionTransformer(utils.is_jour_ferie)
check_lockdown = FunctionTransformer(utils.isLockdown)
cycle_encoding = FunctionTransformer(utils.encode_cyclical_features)
couvre_feu = FunctionTransformer(utils.apply_couvre_feu)

num_features = ['temp', 'precip', 'windspeed', 'visibility']
cat_features = ['france_stay_at_home']


col_transformer = ColumnTransformer(
    transformers=[
        
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(), cat_features)
    ],
    remainder='passthrough'  # This keeps all other columns unchanged
)



pipe = Pipeline([
       # ('add_vacances_et_jours_feries', add_vacances_et_jours_feries),
    ('filter_columns',keep_specific_columns),
    ('is_couvre_feu',couvre_feu),
    ('add_weather', add_weather),
    ('check_lockdown',check_lockdown),
    ('date_encode', date_cols),
    ('rain', FunctionTransformer(create_rain)),
    #('cycle_encoding',cycle_encoding),
    #('scaling_num_features', col_transformer),
    
    ('model', cat)
])


pipe.fit(X_train, y_train)

predictions = pipe.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Fetching lockdown dates...
# Fetched lockdown dates for: France
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[18], line 48
#      22 col_transformer = ColumnTransformer(
#      23     transformers=[
#      24
#    (...)
#      28     remainder='passthrough'  # This keeps all other columns unchanged
#      29 )
#      33 pipe = Pipeline([
#      34        # ('add_vacances_et_jours_feries', add_vacances_et_jours_feries),
#      35     ('filter_columns',keep_specific_columns),
#    (...)
#      44     ('model', cat)
#      45 ])
# ---> 48 pipe.fit(X_train, y_train)
#      50 predictions = pipe.predict(X_test)
#      52 rmse = np.sqrt(mean_squared_error(y_test, predictions))
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/sklearn/pipeline.py:427, in Pipeline.fit(self, X, y, **fit_params)
#     425     if self._final_estimator != "passthrough":
#     426         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 427         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     429 return self
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:5703, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5700 if 'loss_function' in params:
#    5701     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5703 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5704                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5705                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5706                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:2303, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2300 if y is None and not isinstance(X, PATH_TYPES + (Pool,)):
#    2301     raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
# -> 2303 train_params = self._prepare_train_params(
#    2304     X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    2305     pairs=pairs, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#    2306     subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline, use_best_model=use_best_model,
#    2307     eval_set=eval_set, verbose=verbose, logging_level=logging_level, plot=plot, plot_file=plot_file,
#    2308     column_description=column_description, verbose_eval=verbose_eval, metric_period=metric_period,
#    2309     silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    2310     snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    2311     callbacks=callbacks
#    2312 )
#    2313 params = train_params["params"]
#    2314 train_pool = train_params["train_pool"]
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:2184, in CatBoost._prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    2181 text_features = _process_feature_indices(text_features, X, params, 'text_features')
#    2182 embedding_features = _process_feature_indices(embedding_features, X, params, 'embedding_features')
# -> 2184 train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    2185                                sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
#    2186                                baseline, column_description)
#    2187 if train_pool.is_empty_:
#    2188     raise CatBoostError("X is empty.")
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:1444, in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1442     if y is None:
#    1443         raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
# -> 1444     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#    1445                       group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    1446 return train_pool
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:793, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     787         if isinstance(feature_names, PATH_TYPES):
#     788             raise CatBoostError(
#     789                 "feature_names must be None or have non-string type when the pool is created from "
#     790                 "python objects."
#     791             )
# --> 793         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     794                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     795 super(Pool, self).__init__()
#
# File ~/.pyenv/versions/3.10.6/envs/final_pfds/lib/python3.10/site-packages/catboost/core.py:1425, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1423 if feature_tags is not None:
#    1424     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1425 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1426                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3976, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4026, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3842, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2764, in _catboost._set_features_order_data_pd_data_frame()
#
# CatBoostError: features data: pandas.DataFrame column 'france_stay_at_home' has dtype 'category' but is not in  cat_features list

# %%
0.5610473766023862

# %%
def isLockdown(X):
    ld = LockdownDates("France", "2020-09-01", "2021-09-09", ("stay_at_home", "masks"))
    lockdown_dates = ld.dates()
    ld = lockdown_dates.reset_index().rename(columns={'timestamp': 'date_merge'})
    X['date_merge'] = pd.to_datetime(X['date'].dt.strftime('%Y-%m-%d'), format='%Y-%m-%d')
    X_ld = X.merge(ld, how = 'left', on = 'date_merge')
    X_ld = X_ld.drop(['france_masks', 'france_country_code', 'date_merge'], axis=1)
    #X_ld['france_stay_at_home'] = X_ld['france_stay_at_home'].map(lambda x: 1 if x == 2 else 0)\n",
    return X_ld

X_train
# Out:
#                  counter_id                       counter_name    site_id  \
# 400125  100049407-353255860  152 boulevard du Montparnasse E-O  100049407
# 408305  100049407-353255859  152 boulevard du Montparnasse O-E  100049407
# 87516   100036719-104036719  18 quai de l'Hôtel de Ville NO-SE  100036719
# 98518   100036719-103036719  18 quai de l'Hôtel de Ville SE-NO  100036719
# 875137  100063175-353277233          20 Avenue de Clichy NO-SE  100063175
# ...                     ...                                ...        ...
# 794947  100057329-103057329   Totem 85 quai d'Austerlitz SE-NO  100057329
# 804811  100057380-104057380           Totem Cours la Reine E-O  100057380
# 814413  100057380-103057380           Totem Cours la Reine O-E  100057380
# 125926  100042374-110042374        Voie Georges Pompidou NE-SO  100042374
# 133799  100042374-109042374        Voie Georges Pompidou SO-NE  100042374
#
#                             site_name                date  \
# 400125  152 boulevard du Montparnasse 2020-09-01 01:00:00
# 408305  152 boulevard du Montparnasse 2020-09-01 01:00:00
# 87516     18 quai de l'Hôtel de Ville 2020-09-01 01:00:00
# 98518     18 quai de l'Hôtel de Ville 2020-09-01 01:00:00
# 875137            20 Avenue de Clichy 2020-09-01 01:00:00
# ...                               ...                 ...
# 794947     Totem 85 quai d'Austerlitz 2021-08-10 23:00:00
# 804811           Totem Cours la Reine 2021-08-10 23:00:00
# 814413           Totem Cours la Reine 2021-08-10 23:00:00
# 125926          Voie Georges Pompidou 2021-08-10 23:00:00
# 133799          Voie Georges Pompidou 2021-08-10 23:00:00
#
#        counter_installation_date         coordinates counter_technical_id  \
# 400125                2018-12-07  48.840801,2.333233          Y2H19070373
# 408305                2018-12-07  48.840801,2.333233          Y2H19070373
# 87516                 2017-07-12    48.85372,2.35702          Y2H19027732
# 98518                 2017-07-12    48.85372,2.35702          Y2H19027732
# 875137                2020-07-22    48.88529,2.32666          Y2H20073268
# ...                          ...                 ...                  ...
# 794947                2020-02-18    48.84201,2.36729          YTH19111508
# 804811                2020-02-11    48.86462,2.31444          YTH19111509
# 814413                2020-02-11    48.86462,2.31444          YTH19111509
# 125926                2017-12-15     48.8484,2.27586          Y2H21025335
# 133799                2017-12-15     48.8484,2.27586          Y2H21025335
#
#          latitude  longitude date_merge
# 400125  48.840801   2.333233 2020-09-01
# 408305  48.840801   2.333233 2020-09-01
# 87516   48.853720   2.357020 2020-09-01
# 98518   48.853720   2.357020 2020-09-01
# 875137  48.885290   2.326660 2020-09-01
# ...           ...        ...        ...
# 794947  48.842010   2.367290 2021-08-10
# 804811  48.864620   2.314440 2021-08-10
# 814413  48.864620   2.314440 2021-08-10
# 125926  48.848400   2.275860 2021-08-10
# 133799  48.848400   2.275860 2021-08-10
#
# [456507 rows x 11 columns]

# %% [markdown]
# # TEST PIPELINE OUTPUT

# %%
pipe = Pipeline([
    
    ('filter_columns',keep_specific_columns),
    #('add_vacances_et_jours_feries', add_vacances_et_jours_feries),
    ('add_weather', add_weather),
    ('check_lockdown',check_lockdown),
    ('date_encode', FunctionTransformer(_encode_dates)),
    #('cycle_encoding',cycle_encoding),
    #('scaling_num_features', col_transformer),
    #('rain', FunctionTransformer(create_rain))
])

pipe.fit_transform(X)
# Out:
#          latitude  longitude  temp  precip  windspeed  visibility  \
# 0       48.840801   2.333233  16.1    0.00       13.6        25.1
# 1       48.840801   2.333233  16.1    0.00       13.6        25.1
# 2       48.853720   2.357020  16.1    0.00       13.6        25.1
# 3       48.853720   2.357020  16.1    0.00       13.6        25.1
# 4       48.885290   2.326660  16.1    0.00       13.6        25.1
# ...           ...        ...   ...     ...        ...         ...
# 496822  48.842010   2.367290  22.1    2.54       16.6        13.7
# 496823  48.864620   2.314440  22.1    2.54       16.6        13.7
# 496824  48.864620   2.314440  22.1    2.54       16.6        13.7
# 496825  48.848400   2.275860  22.1    2.54       16.6        13.7
# 496826  48.848400   2.275860  22.1    2.54       16.6        13.7
#
#         icon_encoded  index  Lockdown  year  month  day  weekday  hour
# 0                  3      0         0  2020      9    1        1     1
# 1                  3      0         0  2020      9    1        1     1
# 2                  3      0         0  2020      9    1        1     1
# 3                  3      0         0  2020      9    1        1     1
# 4                  3      0         0  2020      9    1        1     1
# ...              ...    ...       ...   ...    ...  ...      ...   ...
# 496822             1    373         0  2021      9    9        3    23
# 496823             1    373         0  2021      9    9        3    23
# 496824             1    373         0  2021      9    9        3    23
# 496825             1    373         0  2021      9    9        3    23
# 496826             1    373         0  2021      9    9        3    23
#
# [496827 rows x 14 columns]

# %%
def apply_couvre_feu(df, date_column='date'):

    couvre_feu_periods = [
        {"start": datetime.datetime(2020, 3, 17), "end": datetime.datetime(2020, 5, 29), "start_time": datetime.time(21, 0), "end_time": datetime.time(6, 0)},
        {"start": datetime.datetime(2021, 1, 16), "end": datetime.datetime(2021, 6, 20), "start_time": datetime.time(21, 0), "end_time": datetime.time(6, 0)},
    ]

    def is_couvre_feu(date_heure):

        if not isinstance(date_heure, str):
            date_heure = date_heure.strftime('%Y-%m-%d %H:%M')

        dt = datetime.datetime.strptime(date_heure, '%Y-%m-%d %H:%M')
        for period in couvre_feu_periods:
            if period["start"].date() <= dt.date() <= period["end"].date():
                if ((dt.time() >= period["start_time"]) or (dt.time() < period["end_time"])):
                    return 1
        return 0

# %% [markdown]
# # Format Output

# %%
pipe.fit(X,y)
submission = pipe.predict(X_final_test)
pd.Series(submission).to_frame().rename_axis('Id').rename(columns={0:'log_bike_count'}).to_csv('submission17_91223.csv')
